# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(
    "ignore", category = UserWarning
)
warnings.filterwarnings(
    "ignore", category = FutureWarning
)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("hr_employee_churn_data.csv")
ordinal_mapping = {
    "low": 1,
    "medium": 2,
    "high": 3
}
df.replace(ordinal_mapping, inplace=True)

# %%
df.head()
# Out:
#    empid  satisfaction_level  last_evaluation  number_project  \
# 0      1                0.38             0.53               2
# 1      2                0.80             0.86               5
# 2      3                0.11             0.88               7
# 3      4                0.72             0.87               5
# 4      5                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years  salary  left
# 0                      0       1     1
# 1                      0       2     1
# 2                      0       2     1
# 3                      0       1     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   empid                  14999 non-null  int64
#  1   satisfaction_level     14997 non-null  float64
#  2   last_evaluation        14999 non-null  float64
#  3   number_project         14999 non-null  int64
#  4   average_montly_hours   14999 non-null  int64
#  5   time_spend_company     14999 non-null  int64
#  6   Work_accident          14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   salary                 14999 non-null  int64
#  9   left                   14999 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 1.1 MB

# %%
df.isnull().sum()
# Out:
# empid                    0
# satisfaction_level       2
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# promotion_last_5years    0
# salary                   0
# left                     0
# dtype: int64

# %%
df.shape
# Out:
# (14999, 10)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#               empid  satisfaction_level  last_evaluation  number_project  \
# count  14999.000000        14997.000000     14999.000000    14999.000000
# mean    7500.000000            0.612863         0.716102        3.803054
# std     4329.982679            0.248634         0.171169        1.232592
# min        1.000000            0.090000         0.360000        2.000000
# 25%     3750.500000            0.440000         0.560000        3.000000
# 50%     7500.000000            0.640000         0.720000        4.000000
# 75%    11249.500000            0.820000         0.870000        5.000000
# max    14999.000000            1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count          14999.000000        14999.000000   14999.000000
# mean             201.050337            3.498233       0.144610
# std               49.943099            1.460136       0.351719
# ...

# %% [markdown]
# ### count: Shows the number of non-missing values in each column
# ### std: Measuers the amount of variation or disperion in the data. A higher standard deviation indicates more spread out data, and a lower standard deviation indicates data that is more closely cluseterd around the mean.
# ### 25%: The value below 25% of the data falls.

# %%
df['Work_accident'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.countplot(x='left', data=df)
plt.show()

# %%
sns.countplot(x='salary', hue='left', data= df)
plt.show()

# %%
sns.catplot(x='left', col = 'salary', kind= 'count', data=df)
plt.show()

# %%
sns.catplot(x='left', col= 'Work_accident', kind = 'count', data=df)
plt.show()

# %%
sns.distplot(df['satisfaction_level'])
# Out:
# <Axes: xlabel='satisfaction_level', ylabel='Density'>

# %%
sns.boxplot(x='left', y='satisfaction_level', data=df)
plt.show()
# take-away: emplyees with low satisfaction level mostly left the organization

# %%
sns.distplot(df['number_project'])
plt.show()

# %%
sns.boxplot(x='left', y='number_project', data=df)
# Out:
# <Axes: xlabel='left', ylabel='number_project'>

# %%
sns.distplot(df['last_evaluation'])
plt.show()

# %%
sns.boxplot(x='left', y='last_evaluation', data=df)
plt.show()

# %%
sns.boxplot(x='left', y='average_montly_hours', data=df) 
plt.show()

# %%
sns.boxplot(x='left', y='time_spend_company', data=df) 
plt.show()

# %%
cor_mat = df.corr()
fig = plt.figure(figsize = (15, 7))
sns.heatmap(cor_mat, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   empid                  14999 non-null  int64
#  1   satisfaction_level     14997 non-null  float64
#  2   last_evaluation        14999 non-null  float64
#  3   number_project         14999 non-null  int64
#  4   average_montly_hours   14999 non-null  int64
#  5   time_spend_company     14999 non-null  int64
#  6   Work_accident          14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   salary                 14999 non-null  int64
#  9   left                   14999 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 1.1 MB

# %%
df2 = df.copy()
df2.drop(['empid'], axis = 1, inplace=True)

# %%
df2.isnull().sum()
# Out:
# satisfaction_level       2
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# promotion_last_5years    0
# salary                   0
# left                     0
# dtype: int64

# %%
df2['satisfaction_level'].fillna(df2['satisfaction_level'].mean(), inplace=True)

# %%
df2.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# promotion_last_5years    0
# salary                   0
# left                     0
# dtype: int64

# %%
df2['satisfaction_level'].describe()
# Out:
# count    14999.000000
# mean         0.612863
# std          0.248618
# min          0.090000
# 25%          0.440000
# 50%          0.640000
# 75%          0.820000
# max          1.000000
# Name: satisfaction_level, dtype: float64

# %%
df2['satisfaction_level'].fillna(df2['satisfaction_level'].mean(), inplace = True)

# %%
df2.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# promotion_last_5years    0
# salary                   0
# left                     0
# dtype: int64

# %%
salary_dummies = pd.get_dummies(df2['salary'], drop_first = True)

# %%
df2 = pd.concat([df2, salary_dummies], axis =1)

# %%
df2.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years  salary  left  \
# 0                   3              0                      0       1     1
# 1                   6              0                      0       2     1
# 2                   4              0                      0       2     1
# 3                   5              0                      0       1     1
# 4                   3              0                      0       1     1
#
#        2      3
# 0  False  False
# 1   True  False
# ...

# %%
df2.drop(['salary'], axis = 1, inplace = True)

# %%
df2.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years  left      2  \
# 0                   3              0                      0     1  False
# 1                   6              0                      0     1   True
# 2                   4              0                      0     1   True
# 3                   5              0                      0     1  False
# 4                   3              0                      0     1  False
#
#        3
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %% [markdown]
# # Split the dataset into Training and Test set

# %%
X = df2.drop(labels = 'left', axis = 1)
y = df2['left']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
len(X_train)
# Out:
# 11999

# %%
len(X_test)
# Out:
# 3000

# %%
pip install xgboost
# Out:
# ...
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/24/ec/ad387100fa3cc2b9b81af0829b5ecfe75ec5bb19dd7c19d4fea06fb81802/xgboost-2.0.3-py3-none-win_amd64.whl.metadata
#   Using cached xgboost-2.0.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# ...
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 2
#       1 from sklearn.ensemble import RandomForestClassifier
# ----> 2 from xgboost import XGBClassifier
#       3 from sklearn.model_selection import GridSearchCV
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
model_param = {
    'RandomForestClassifier()':{
        'model' : RandomForestClassifier(),
        'param':{
            'n_estimators': [10, 50, 100, 130],
            'criterion': ['gin1', 'entropy'],
            'max_depth': range(2, 4, 1),
            'max_features': ['auto', 'log2']
        }
    },
    'XGBClassfier':{
        'model' : XGBClassifier(objective = 'binary:logistic'),
        'param':{
            'learning_rate': [0.5, 0.1, 0.01, 0.001],
            'max_depth': [3, 5, 20],
            'n_estimators': [10, 50, 100, 200]
        }
    }
}

# %%
scores = []
for model_name, mp in model_param.items():
    model_selection = GridSearchCV(estimator=mp['model'], param_grid= mp['param'], cv = 5, return_train_score = False)
    model_selection,fit(X, y)
    scores.append({
        'model': model_name,
        'best_score': model_selection.best_score_,
        'best_params': model_selection.best_params
    })

# %%
model_xgb = XGBClassifier(objective = 'binary:logistic', learning_rate = 0.1, max_depth = 28, n_estimators = 200)

# %%
model_xgb.fit(X_train, y_train)

# %%
model_xgb.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 model_xgb.score(X_test, y_test)
#
# NameError: name 'model_xgb' is not defined

# %%
model_xgb.predict(X_test[:1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 model_xgb.predict(X_test[:1])
#
# NameError: name 'model_xgb' is not defined

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, model_xgb.predict(X_test))
cm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 cm = confusion_matrix(y_test, model_xgb.predict(X_test))
#       3 cm
#
# NameError: name 'model_xgb' is not defined

# %%
sns.heatmap(cm, annot = True)
plt.x_label("Predicted")
plt.y_label("True Value")
plt.show()
